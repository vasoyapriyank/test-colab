# %% [markdown]
# <a href="https://colab.research.google.com/github/vasoyapriyank/test-colab/blob/main/Lecture%20notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input('what name? ')

match name:
  case 'apple'|'banana'|'orange':
    print('fruit')
  case 'potato'|'tomato'|'letuce':
    print('vegetable')
  case _:
    print('unkn')
# Out:
# what name? onion
# unkn

# %%
i=3
while i!=0:
  print('meow')
  i-=1
# Out:
# meow
# meow
# meow

# %%
for _ in range(3):
  print('meow')
# Out:
# meow
# meow
# meow

# %%
def main():
  num=get_number()
  meow(num)

def get_number():
  while True:
    n=int(input('What\'s n? '))
    if n>0:
      return n

def meow(n):
  for _ in range(n):
    print('meow')

main()
# Out:
# What's n? 2
# meow
# meow

# %%
def main():
  x=number()
  meow(x)

def meow(n):
  for _ in range (n):
    print('meow')

def number():
  while True:
    n=int(input('What\'s the number?'))
    if n > 0:
      return n

main()
# Out:
# What's the number?5
# meow
# meow
# meow
# meow
# meow
